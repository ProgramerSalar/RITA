# %%
video_path = "./part_1/credit_risk_modeling/The Mathematics Used By Quant Trading Firms #investing #trading #shorts [B9o2ZqJgszw].mp4"

import glob 
checking_video_path = glob.glob(glob.escape(video_path))
print(checking_video_path)
# Out:
# []

# %%
import glob

video_path = "./part_1/credit_risk_modeling/The Mathematics Used By Quant Trading Firms #investing #trading #shorts [B9o2ZqJgszw].mp4"

# Escape the special characters automatically
escaped_path = glob.escape(video_path)

print(f"Escaped Path: {escaped_path}") 
# Output will look like: ...shorts [[]B9o2ZqJgszw[]].mp4

checking_video_path = glob.glob(escaped_path)
print(checking_video_path)
# Out:
# Escaped Path: ./part_1/credit_risk_modeling/The Mathematics Used By Quant Trading Firms #investing #trading #shorts [[]B9o2ZqJgszw].mp4
# []

# %%
# video_path = "./part_1/credit_risk_modeling/The Mathematics Used By Quant Trading Firms #investing #trading #shorts [B9o2ZqJgszw].mp4"
video_path = "../part_1/computational_geomet/computational_geomet_103575.mp4"
import os 
if os.path.exists(video_path):
    print('working...')
else:
    print('not working...')
# Out:
# working...

# %%
import numpy

numpy.random.randint(1, 100)
# Out:
# 77
